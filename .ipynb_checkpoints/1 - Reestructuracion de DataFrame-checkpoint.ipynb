# %%
import pandas as pd

# %%
datos = pd.read_csv('../Archivos/carpetas-de-investigacion-pgj-cdmx.csv')
datos.head(2)
# Out:
#    año_hechos mes_hechos         fecha_hechos  \
# 0      2016.0      Enero  2016-01-05 17:00:00
# 1      2017.0  Noviembre  2017-11-01 14:00:00
#
#                                               delito  \
# 0                                  LESIONES CULPOSAS
# 1  ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VI...
#
#                        categoria_delito                            fiscalía  \
# 0                DELITO DE BAJO IMPACTO  INVESTIGACIÓN EN GUSTAVO A. MADERO
# 1  ROBO DE VEHÍCULO CON Y SIN VIOLENCIA       INVESTIGACIÓN EN AZCAPOTZALCO
#
#   agencia unidad_investigacion    colonia_hechos      alcaldia_hechos  \
# 0   GAM-6               UI-1CD  GRANJAS MODERNAS     GUSTAVO A MADERO
# 1    AZ-1               UI-1SD               NaN  TLALNEPANTLA DE BAZ
#
#           fecha_inicio mes_inicio  ao_inicio        calle_hechos  \
# 0  2016-01-05 18:35:37      Enero       2016  SAN JUAN DE ARAGON
# 1  2017-11-01 16:45:20  Noviembre       2017       BENITO JUAREZ
#
# ...

# %%
datos.columns
# Out:
# Index(['año_hechos', 'mes_hechos', 'fecha_hechos', 'delito',
#        'categoria_delito', 'fiscalía', 'agencia', 'unidad_investigacion',
#        'colonia_hechos', 'alcaldia_hechos', 'fecha_inicio', 'mes_inicio',
#        'ao_inicio', 'calle_hechos', 'calle_hechos2', 'longitud', 'latitud',
#        'Geopoint'],
#       dtype='object')

# %%
datos_GAM = datos[datos['alcaldia_hechos']=='GUSTAVO A MADERO']
datos_GAM.head()
# Out:
#     año_hechos  mes_hechos         fecha_hechos  \
# 0       2016.0       Enero  2016-01-05 17:00:00
# 9       2016.0  Septiembre  2016-09-23 12:00:00
# 16      2017.0     Octubre  2017-10-31 21:30:00
# 33      2018.0        Mayo  2018-05-21 09:00:00
# 34      2016.0       Enero  2016-01-07 08:55:00
#
#                                              delito  \
# 0                                 LESIONES CULPOSAS
# 9                                            FRAUDE
# 16  DAÑO EN PROPIEDAD AJENA INTENCIONAL A AUTOMOVIL
# 33                               VIOLENCIA FAMILIAR
# 34   ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA
#
#                                      categoria_delito  \
# 0                              DELITO DE BAJO IMPACTO
# 9                              DELITO DE BAJO IMPACTO
# 16                             DELITO DE BAJO IMPACTO
# 33                             DELITO DE BAJO IMPACTO
# 34  ROBO A TRANSEUNTE EN VÍA PÚBLICA CON Y SIN VIO...
#
# ...

# %%
crimenes = datos_GAM.drop(['año_hechos', 'mes_hechos', 'fiscalía', 'agencia', 'unidad_investigacion',
       'alcaldia_hechos','fecha_inicio', 'mes_inicio','ao_inicio', 'calle_hechos', 'calle_hechos2','Geopoint'], axis=1)
crimenes.head()
# Out:
#            fecha_hechos                                           delito  \
# 0   2016-01-05 17:00:00                                LESIONES CULPOSAS
# 9   2016-09-23 12:00:00                                           FRAUDE
# 16  2017-10-31 21:30:00  DAÑO EN PROPIEDAD AJENA INTENCIONAL A AUTOMOVIL
# 33  2018-05-21 09:00:00                               VIOLENCIA FAMILIAR
# 34  2016-01-07 08:55:00   ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA
#
#                                      categoria_delito  \
# 0                              DELITO DE BAJO IMPACTO
# 9                              DELITO DE BAJO IMPACTO
# 16                             DELITO DE BAJO IMPACTO
# 33                             DELITO DE BAJO IMPACTO
# 34  ROBO A TRANSEUNTE EN VÍA PÚBLICA CON Y SIN VIO...
#
#                   colonia_hechos   longitud    latitud
# 0               GRANJAS MODERNAS -99.103527  19.481076
# 9                     LA PRADERA -99.071243  19.475715
# ...

# %%
crimenes.shape
# Out:
# (80097, 6)

# %%
crimenes.rename(columns={'fecha_hechos':'fecha',
                        'delito':'crimen',
                        'categoria_delito':'categoria',
                        'colonia_hechos':'colonia',
                        'longitud': 'long',
                        'latitud': 'lat'}, inplace=True)
crimenes.head()
# Out:
#                   fecha                                           crimen  \
# 0   2016-01-05 17:00:00                                LESIONES CULPOSAS
# 9   2016-09-23 12:00:00                                           FRAUDE
# 16  2017-10-31 21:30:00  DAÑO EN PROPIEDAD AJENA INTENCIONAL A AUTOMOVIL
# 33  2018-05-21 09:00:00                               VIOLENCIA FAMILIAR
# 34  2016-01-07 08:55:00   ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA
#
#                                             categoria  \
# 0                              DELITO DE BAJO IMPACTO
# 9                              DELITO DE BAJO IMPACTO
# 16                             DELITO DE BAJO IMPACTO
# 33                             DELITO DE BAJO IMPACTO
# 34  ROBO A TRANSEUNTE EN VÍA PÚBLICA CON Y SIN VIO...
#
#                          colonia       long        lat
# 0               GRANJAS MODERNAS -99.103527  19.481076
# 9                     LA PRADERA -99.071243  19.475715
# ...

# %%
crimenes.to_csv('../Archivos/crimenes-GAM-todos.csv', index=False)
